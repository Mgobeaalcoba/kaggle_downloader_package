# %%
! pip install kaggle-downloader-package
# Out:
# ...
#   Using cached psycopg2-2.9.9-cp312-cp312-macosx_11_0_arm64.whl
# ...
#   Using cached SQLAlchemy-2.0.35-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.6 kB)
# ...
#   Using cached setuptools-75.1.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached pydata_google_auth-1.8.2-py2.py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 4.3 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 9.2 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Using cached SQLAlchemy-2.0.35-cp312-cp312-macosx_11_0_arm64.whl (2.1 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.2/142.2 kB 10.4 MB/s eta 0:00:00
# ...

# %%
import kaggle_downloader_package as kd

downloader = kd.KaggleDownloader()

downloader.authenticate_kaggle()
# Out:
# Kaggle authentication successful with credentials in ./kaggle.json

# %%
downloader.search_datasets("futbol")
# Out:
# ref                                                                 title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# ramnquintana/resultados-de-futbol-entre-1872-y-2017                  Resultados de futbol entre 1872 y 2017             529KB  2019-11-06 13:51:21           2346         40  0.85294116
# estebanmarcelloni/liga-argentina-futbol                             Liga Argentina Fútbol                               281KB  2022-03-28 17:39:07           2358         38  1.0
# isabelocastillo/jugadores-de-futbol-de-la-rfef-temporada-2023-2024  Jugadores de futbol de la RFEF temporada 2023-2024  230KB  2024-09-10 08:01:37             52          5  1.0
# ...

# %%
downloader.download_dataset("estebanmarcelloni/liga-argentina-futbol")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/estebanmarcelloni/liga-argentina-futbol
# License(s): CC0-1.0
# ...
#
#
# Dataset 'estebanmarcelloni/liga-argentina-futbol' downloaded successfully to .

# %%
import pandas as pd
df = pd.read_csv("/Users/mgobea/Documents/Personal_Develop/kaggle_downloader_package/examples/results.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32854 entries, 0 to 32853
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       32854 non-null  int64
#  1   date_name        32854 non-null  object
#  2   local_team_id    32854 non-null  int64
#  3   local_team       32854 non-null  object
#  4   local_result     32854 non-null  int64
#  5   visitor_result   32854 non-null  int64
#  6   visitor_team     32854 non-null  object
#  7   visitor_team_id  32854 non-null  int64
# dtypes: int64(5), object(3)
# memory usage: 2.0+ MB

# %%
df.head()
# Out:
#    Unnamed: 0                     date_name  local_team_id  local_team  \
# 0           0       Nacional 1976 - Grupo C              1    All Boys
# 1           1       Nacional 1976 - Grupo C              0    Aldosivi
# 2           2   Superliga 2019/20 - Fecha 2              0    Aldosivi
# 3           3  Superliga 2018/19 - Fecha 15              7  Argentinos
# 4           4         Torneo 2016 - Fecha 2              0    Aldosivi
#
#    local_result  visitor_result visitor_team  visitor_team_id
# 0             2               0     Aldosivi                0
# 1             4               0     All Boys                1
# 2             0               0   Argentinos                7
# 3             1               2     Aldosivi                0
# 4             3               2   Argentinos                7
